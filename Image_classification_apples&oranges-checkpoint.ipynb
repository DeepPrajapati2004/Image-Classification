# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os

# %%
img=image.load_img("Basedata/Training/Apples/apple  1.png")

# %%
plt.imshow(img)

# %%
cv2.imread(r"A:\Python\Image_classification_project\Basedata\Training\Apples\apple  1.png").shape
# Out:
# (618, 641, 3)

# %%
train = ImageDataGenerator(rescale=1/255)
validation=ImageDataGenerator(rescale=1/255)

# %%
train_dataset=train.flow_from_directory("Basedata/Training/",
                                        target_size=(200,200),
                                        batch_size=2,
                                        class_mode='binary')
validation_dataset=validation.flow_from_directory("Basedata/Validation/",
                                        target_size=(200,200),
                                        batch_size=2,
                                        class_mode='binary')
# Out:
# Found 20 images belonging to 2 classes.
# Found 12 images belonging to 2 classes.

# %%
model=tf.keras.models.Sequential([ tf.keras.layers.Conv2D(16,(3,3),
                                  activation= 'relu',
                                  input_shape=(200,200,3)),
                                  tf.keras.layers.MaxPool2D(2,2),
                                  #
                                  tf.keras.layers.Conv2D(32,(3,3),
                                  activation= 'relu'),
                                  tf.keras.layers.MaxPool2D(2,2),
                                  #
                                  tf.keras.layers.Conv2D(64,(3,3),
                                  activation= 'relu'),
                                  tf.keras.layers.MaxPool2D(2,2),
                                  ##
                                  tf.keras.layers.Flatten(),
                                  ##
                                  tf.keras.layers.Dense(128,activation= 'relu'),
                                  ##
                                  tf.keras.layers.Dense(1,activation='sigmoid')
])

# %%
model.compile(loss= 'binary_crossentropy',
              optimizer = tf.keras.optimizers.RMSprop(learning_rate= 0.001),
              metrics=['accuracy'])

# %%
model_fit=model.fit(train_dataset,
                   steps_per_epoch=4,
                   epochs=40,
                   validation_data=validation_dataset)
# Out:
# Epoch 1/40
# 4/4 [==============================] - 1s 154ms/step - loss: 2.6536e-06 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 2/40
# 4/4 [==============================] - 1s 163ms/step - loss: 1.0283e-06 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 3/40
# 4/4 [==============================] - 1s 161ms/step - loss: 8.5985e-07 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 1.0000
# Epoch 4/40
# 4/4 [==============================] - 1s 142ms/step - loss: 1.2982e-06 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 1.0000
# Epoch 5/40
# 4/4 [==============================] - 1s 144ms/step - loss: 1.4088e-06 - accuracy: 1.0000 - val_loss: 0.0297 - val_accuracy: 1.0000
# Epoch 6/40
# 4/4 [==============================] - 1s 173ms/step - loss: 2.8094e-06 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 7/40
# ...

# %%
dir_path="A:/Python/Image_classification_project/Basedata/Testing"
c=['Apple','Orange']
for i in os.listdir(dir_path):
    print(dir_path+'/'+i)
# Out:
# A:/Python/Image_classification_project/Basedata/Testing/Apples
# A:/Python/Image_classification_project/Basedata/Testing/Oranges

# %%
dir_path = "Basedata/Testing"
for i in os.listdir(dir_path):
    for j in range(1,7):
        img = image.load_img(dir_path+ '/' + i +'/'+'img'+str(j)+'.jpg', target_size=(200, 200))
        plt.imshow(img)
        plt.show()
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        images = np.vstack([x])

        c =model.predict(images)
        if c[0]==0:
            print("You ara not happy")
        else:
            print("you are happy")
